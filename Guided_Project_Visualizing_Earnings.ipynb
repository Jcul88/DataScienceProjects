# %%
import matplotlib.pyplot as plt
import pandas as pd
% matplotlib inline
recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
#
raw_data_count = recent_grads.shape
raw_data_count
# Out:
# (173, 21)

# %% [markdown]
# Remove rows containing missing values from the dataframe.

# %%
recent_grads = recent_grads.dropna()#removing missing values from the data frame
cleaned_data_count = recent_grads.shape
cleaned_data_count
# Out:
# (172, 21)

# %%
recent_grads.plot(x="Sample_size", y="Median", kind='scatter', title='Sample_size v Median')

# %% [markdown]
# With increase in sample size (unweighted) of employable full-time graduates, the median salary decreased

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind='scatter')

# %%
recent_grads.plot(x="Full_time", y="Median", kind='scatter')

# %% [markdown]
# From the figure above, Median salary of full-time year-round workers decreases with the number of people employed for Full time 35 hours or more.

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind='scatter')

# %%
recent_grads.plot(x="Men", y="Median", kind='scatter')

# %%
recent_grads.plot(x="Women", y="Median", kind='scatter')

# %% [markdown]
# From the figure above, Median salary of full-time year-round workers decreases as the number of female graduate increases. Suggesting that a large number of female graduates earn less compared to a just a few.

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0, 3500))

# %%
recent_grads['Median'].plot(kind='hist')

# %% [markdown]
# The figure reveals that most graduates earn between 30,000 and 40,000 in salaries. Suggesting this as the most common salary range earned by full time workers.

# %%
recent_grads['Employed'].hist(bins=25, range=(0, 100000))

# %% [markdown]
# The number of people employed differs accross the major disciplines. This also suggests that the number of employed accross majors is not normally distributed. We can also observe some data points that are beyond what we expect (outliers).

# %%
recent_grads['Full_time'].hist(bins=25, range=(0, 100000))

# %%
recent_grads['ShareWomen'].plot(kind='hist')

# %%
recent_grads['Unemployment_rate'].plot(kind='hist')

# %% [markdown]
# The number of unemployed people seems normally distributed and that unemployment rate is often between 6% and 8%. We do not however observe outliers from this data.

# %%
recent_grads['Men'].hist(bins=25, range=(0, 140000))

# %%
recent_grads['Women'].hist(bins=25, range=(0, 140000))

# %%
from pandas.plotting import scatter_matrix#imports scatter matrix 
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efdd3026cf8>,
# ...
#       dtype=object)

# %% [markdown]
# Because scatter matrix plots are frequently used in the exploratory data analysis, pandas contains a function named scatter_matrix() that generates the plots for us. This function is part of the pandas.plotting module and needs to be imported separately.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7efdd30527b8>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[162:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# Result from the first ten rows indicates high proportion women graduating with Astronomy & Astrophysics compared to percentage of women in other Majors.

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# Bar plots compare the unemployment rate (Unemployment_rate) between Majors from the first and last ten rows. Clinical Psychology Major has the highest unemployment rate for the last ten data points, while Early Childhood Education has the lowest unemployment rate among the last ten data points.
#
# For the first ten rows, Nuclear Engineering Major has the highest unemployment rate, while Petroleum Engineering, Metallurgical Engineering and Astronomy & Astrophysics have the lowest unemployment rates.
